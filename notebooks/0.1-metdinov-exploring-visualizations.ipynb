# %%
import os
import backtester as bt
from backtester.utils import get_data_dir

data_dir = get_data_dir()
spx_data = os.path.join(data_dir, "SPX_2008-2018.csv")
port = bt.run(spx_data)
report = port.create_report()

# %%
from backtester.statistics import charts
import altair as alt
alt.renderers.enable("notebook")
# Out:
# RendererRegistry.enable('notebook')

# %%
report.tail(20)
# Out:
#              Cash  SPX Amount  SPX Exposure  SPX Open  Total Exposure  \
# 2018-11-30  12.44       691.0    1907270.56   1447.16      1907270.56
# 2018-12-03  12.44       691.0    1928145.67   1447.16      1928145.67
# 2018-12-04  12.44       691.0    1865741.46   1447.16      1865741.46
# 2018-12-06  12.44       691.0    1862901.45   1447.16      1862901.45
# 2018-12-07  12.44       691.0    1819396.09   1447.16      1819396.09
# 2018-12-10  12.44       691.0    1822664.52   1447.16      1822664.52
# 2018-12-11  12.44       691.0    1822014.98   1447.16      1822014.98
# 2018-12-12  12.44       691.0    1831889.37   1447.16      1831889.37
# 2018-12-13  12.44       691.0    1831523.14   1447.16      1831523.14
# 2018-12-14  12.44       691.0    1796565.45   1447.16      1796565.45
# 2018-12-17  12.44       691.0    1759244.54   1447.16      1759244.54
# 2018-12-18  12.44       691.0    1759396.56   1447.16      1759396.56
# 2018-12-19  12.44       691.0    1732309.36   1447.16      1732309.36
# 2018-12-20  12.44       691.0    1704980.31   1447.16      1704980.31
# 2018-12-21  12.44       691.0    1669891.33   1447.16      1669891.33
# 2018-12-24  12.44       691.0    1624610.10   1447.16      1624610.10
# 2018-12-26  12.44       691.0    1705180.70   1447.16      1705180.70
# 2018-12-27  12.44       691.0    1719781.53   1447.16      1719781.53
# 2018-12-28  12.44       691.0    1717646.34   1447.16      1717646.34
# 2018-12-31  12.44       691.0    1732233.35   1447.16      1732233.35
#
#             Total Portfolio  Interval Change   % Price
# 2018-11-30       1907283.00         0.008167  0.907283
# 2018-12-03       1928158.11         0.010945  0.928158
# 2018-12-04       1865753.90        -0.032365  0.865754
# 2018-12-06       1862913.89        -0.001522  0.862914
# 2018-12-07       1819408.53        -0.023353  0.819409
# 2018-12-10       1822676.96         0.001796  0.822677
# 2018-12-11       1822027.42        -0.000356  0.822027
# 2018-12-12       1831901.81         0.005419  0.831902
# 2018-12-13       1831535.58        -0.000200  0.831536
# 2018-12-14       1796577.89        -0.019087  0.796578
# 2018-12-17       1759256.98        -0.020773  0.759257
# 2018-12-18       1759409.00         0.000086  0.759409
# 2018-12-19       1732321.80        -0.015396  0.732322
# 2018-12-20       1704992.75        -0.015776  0.704993
# 2018-12-21       1669903.77        -0.020580  0.669904
# 2018-12-24       1624622.54        -0.027116  0.624623
# 2018-12-26       1705193.14         0.049593  0.705193
# 2018-12-27       1719793.97         0.008563  0.719794
# 2018-12-28       1717658.78        -0.001242  0.717659
# 2018-12-31       1732245.79         0.008492  0.732246

# %%
returns_chart = charts.returns_chart(report)
returns_chart

# %%
returns_histogram = charts.returns_histogram(report)
returns_histogram

# %%
monthly_returns_hm = charts.monthly_returns_heatmap(report)
monthly_returns_hm
